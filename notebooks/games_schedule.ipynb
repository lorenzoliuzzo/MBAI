# %%
import pandas as pd

# %%
from nba_api.stats.endpoints import ScheduleLeagueV2

ScheduleLeagueV2?
# Out:
# Init signature:
# ScheduleLeagueV2(
#     league_id='00',
#     season='2024-25',
#     proxy=None,
#     headers=None,
#     timeout=30,
#     get_request=True,
# )
# Docstring:      <no docstring>
# File:           ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/nba_api/stats/endpoints/scheduleleaguev2.py
# Type:           type
# Subclasses:

# %%
schedule = ScheduleLeagueV2()

# %%
schedule_df = schedule.get_data_frames()[0]

# %%
schedule_df.columns.to_list()
# Out:
# ['leagueId',
#  'seasonYear',
#  'gameDate',
#  'gameId',
#  'gameCode',
#  'gameStatus',
#  'gameStatusText',
#  'gameSequence',
#  'gameDateEst',
#  'gameTimeEst',
#  'gameDateTimeEst',
#  'gameDateUTC',
#  'gameTimeUTC',
#  'gameDateTimeUTC',
#  'awayTeamTime',
#  'homeTeamTime',
#  'day',
#  'monthNum',
#  'weekNumber',
#  'weekName',
#  'ifNecessary',
#  'seriesGameNumber',
#  'gameLabel',
#  'gameSubLabel',
#  'seriesText',
#  'arenaName',
#  'arenaState',
#  'arenaCity',
#  'postponedStatus',
#  'branchLink',
#  'gameSubtype',
#  'isNeutral',
#  'homeTeam_teamId',
#  'homeTeam_teamName',
#  'homeTeam_teamCity',
#  'homeTeam_teamTricode',
#  'homeTeam_teamSlug',
#  'homeTeam_wins',
#  'homeTeam_losses',
#  'homeTeam_score',
#  'homeTeam_seed',
#  'awayTeam_teamId',
#  'awayTeam_teamName',
#  'awayTeam_teamCity',
#  'awayTeam_teamTricode',
#  'awayTeam_teamSlug',
#  'awayTeam_wins',
#  'awayTeam_losses',
#  'awayTeam_score',
#  'awayTeam_seed',
#  'pointsLeaders_0_personId',
#  'pointsLeaders_0_firstName',
#  'pointsLeaders_0_lastName',
#  'pointsLeaders_0_teamId',
#  'pointsLeaders_0_teamCity',
#  'pointsLeaders_0_teamName',
#  'pointsLeaders_0_teamTricode',
#  'pointsLeaders_0_points',
#  'pointsLeaders_1_personId',
#  'pointsLeaders_1_firstName',
#  'pointsLeaders_1_lastName',
#  'pointsLeaders_1_teamId',
#  'pointsLeaders_1_teamCity',
#  'pointsLeaders_1_teamName',
#  'pointsLeaders_1_teamTricode',
#  'pointsLeaders_1_points',
#  'pointsLeaders_2_personId',
#  'pointsLeaders_2_firstName',
#  'pointsLeaders_2_lastName',
#  'pointsLeaders_2_teamId',
#  'pointsLeaders_2_teamCity',
#  'pointsLeaders_2_teamName',
#  'pointsLeaders_2_teamTricode',
#  'pointsLeaders_2_points',
#  'pointsLeaders_3_personId',
#  'pointsLeaders_3_firstName',
#  'pointsLeaders_3_lastName',
#  'pointsLeaders_3_teamId',
#  'pointsLeaders_3_teamCity',
#  'pointsLeaders_3_teamName',
#  'pointsLeaders_3_teamTricode',
#  'pointsLeaders_3_points',
#  'nationalBroadcasters_broadcasterScope',
#  'nationalBroadcasters_broadcasterMedia',
#  'nationalBroadcasters_broadcasterId',
#  'nationalBroadcasters_broadcasterDisplay',
#  'nationalBroadcasters_broadcasterAbbreviation',
#  'nationalBroadcasters_broadcasterDescription',
#  'nationalBroadcasters_tapeDelayComments',
#  'nationalBroadcasters_broadcasterVideoLink',
#  'nationalBroadcasters_broadcasterTeamId',
#  'nationalBroadcasters_broadcasterRanking',
#  'nationalBroadcasters_localizationRegion',
#  'nationalRadioBroadcasters_0_broadcasterScope',
#  'nationalRadioBroadcasters_0_broadcasterMedia',
#  'nationalRadioBroadcasters_0_broadcasterId',
#  'nationalRadioBroadcasters_0_broadcasterDisplay',
#  'nationalRadioBroadcasters_0_broadcasterAbbreviation',
#  'nationalRadioBroadcasters_0_broadcasterDescription',
#  'nationalRadioBroadcasters_0_tapeDelayComments',
#  'nationalRadioBroadcasters_0_broadcasterVideoLink',
#  'nationalRadioBroadcasters_0_broadcasterTeamId',
#  'nationalRadioBroadcasters_0_broadcasterRanking',
#  'nationalRadioBroadcasters_0_localizationRegion',
#  'nationalRadioBroadcasters_1_broadcasterScope',
#  'nationalRadioBroadcasters_1_broadcasterMedia',
#  'nationalRadioBroadcasters_1_broadcasterId',
#  'nationalRadioBroadcasters_1_broadcasterDisplay',
#  'nationalRadioBroadcasters_1_broadcasterAbbreviation',
#  'nationalRadioBroadcasters_1_broadcasterDescription',
#  'nationalRadioBroadcasters_1_tapeDelayComments',
#  'nationalRadioBroadcasters_1_broadcasterVideoLink',
#  'nationalRadioBroadcasters_1_broadcasterTeamId',
#  'nationalRadioBroadcasters_1_broadcasterRanking',
#  'nationalRadioBroadcasters_1_localizationRegion',
#  'homeTvBroadcasters_broadcasterScope',
#  'homeTvBroadcasters_broadcasterMedia',
#  'homeTvBroadcasters_broadcasterId',
#  'homeTvBroadcasters_broadcasterDisplay',
#  'homeTvBroadcasters_broadcasterAbbreviation',
#  'homeTvBroadcasters_broadcasterDescription',
#  'homeTvBroadcasters_tapeDelayComments',
#  'homeTvBroadcasters_broadcasterVideoLink',
#  'homeTvBroadcasters_broadcasterTeamId',
#  'homeTvBroadcasters_broadcasterRanking',
#  'homeTvBroadcasters_localizationRegion',
#  'homeRadioBroadcasters_broadcasterScope',
#  'homeRadioBroadcasters_broadcasterMedia',
#  'homeRadioBroadcasters_broadcasterId',
#  'homeRadioBroadcasters_broadcasterDisplay',
#  'homeRadioBroadcasters_broadcasterAbbreviation',
#  'homeRadioBroadcasters_broadcasterDescription',
#  'homeRadioBroadcasters_tapeDelayComments',
#  'homeRadioBroadcasters_broadcasterVideoLink',
#  'homeRadioBroadcasters_broadcasterTeamId',
#  'homeRadioBroadcasters_broadcasterRanking',
#  'homeRadioBroadcasters_localizationRegion',
#  'awayTvBroadcasters_broadcasterScope',
#  'awayTvBroadcasters_broadcasterMedia',
#  'awayTvBroadcasters_broadcasterId',
#  'awayTvBroadcasters_broadcasterDisplay',
#  'awayTvBroadcasters_broadcasterAbbreviation',
#  'awayTvBroadcasters_broadcasterDescription',
#  'awayTvBroadcasters_tapeDelayComments',
#  'awayTvBroadcasters_broadcasterVideoLink',
#  'awayTvBroadcasters_broadcasterTeamId',
#  'awayTvBroadcasters_broadcasterRanking',
#  'awayTvBroadcasters_localizationRegion',
#  'awayRadioBroadcasters_broadcasterScope',
#  'awayRadioBroadcasters_broadcasterMedia',
#  'awayRadioBroadcasters_broadcasterId',
#  'awayRadioBroadcasters_broadcasterDisplay',
#  'awayRadioBroadcasters_broadcasterAbbreviation',
#  'awayRadioBroadcasters_broadcasterDescription',
#  'awayRadioBroadcasters_tapeDelayComments',
#  'awayRadioBroadcasters_broadcasterVideoLink',
#  'awayRadioBroadcasters_broadcasterTeamId',
#  'awayRadioBroadcasters_broadcasterRanking',
#  'awayRadioBroadcasters_localizationRegion']

# %%
cols2keep = [
    'gameId', 'gameDateUTC', 'gameTimeUTC', 
    'arenaName', 'arenaState', 'arenaCity', 
    'homeTeam_teamId', 'awayTeam_teamId'
]

# %%
schedule_df[cols2keep]
# Out:
#           gameId           gameDateUTC           gameTimeUTC  \
# 0     0012400001  2024-10-04T04:00:00Z  1900-01-01T16:00:00Z
# 1     0012400002  2024-10-04T04:00:00Z  1900-01-01T01:00:00Z
# 2     0012400003  2024-10-04T04:00:00Z  1900-01-01T02:30:00Z
# 3     0012400004  2024-10-05T04:00:00Z  1900-01-01T23:00:00Z
# 4     0012400005  2024-10-06T04:00:00Z  1900-01-01T14:00:00Z
# ...          ...                   ...                   ...
# 1395  0042400403  2025-06-11T04:00:00Z  1900-01-01T00:30:00Z
# 1396  0042400404  2025-06-13T04:00:00Z  1900-01-01T00:30:00Z
# 1397  0042400405  2025-06-16T04:00:00Z  1900-01-01T00:30:00Z
# 1398  0042400406  2025-06-19T04:00:00Z  1900-01-01T00:30:00Z
# 1399  0042400407  2025-06-22T04:00:00Z  1900-01-01T00:00:00Z
#
#                   arenaName arenaState       arenaCity  homeTeam_teamId  \
# 0              Etihad Arena                  Abu Dhabi       1610612743
# 1              Delta Center         UT  Salt Lake City       1610612762
# 2            Acrisure Arena         CA     Palm Desert       1610612747
# 3       Stan Sheriff Center         HI        Honolulu       1610612746
# 4              Etihad Arena                  Abu Dhabi       1610612738
# ...                     ...        ...             ...              ...
# 1395  Gainbridge Fieldhouse         IN    Indianapolis       1610612754
# 1396  Gainbridge Fieldhouse         IN    Indianapolis       1610612754
# 1397          Paycom Center         OK   Oklahoma City       1610612760
# 1398  Gainbridge Fieldhouse         IN    Indianapolis       1610612754
# 1399          Paycom Center         OK   Oklahoma City       1610612760
#
#       awayTeam_teamId
# 0          1610612738
# 1               15020
# 2          1610612750
# 3          1610612744
# 4          1610612743
# ...               ...
# 1395       1610612760
# 1396       1610612760
# 1397       1610612754
# 1398       1610612760
# 1399       1610612754
#
# [1400 rows x 8 columns]

# %%
df = pd.DataFrame()

# %%
df['GAME_ID'] = schedule_df['gameId'].astype('string')

# %%
dates = pd.to_datetime(schedule_df['gameDateUTC']).dt.normalize()
times = pd.to_datetime(schedule_df['gameTimeUTC']).dt.time
time_deltas = pd.to_timedelta(times.astype(str))

df['GAME_DATE'] = dates + time_deltas

# %%
df['ARENA_NAME'] = schedule_df['arenaName'].astype('string')
df['ARENA_STATE'] = schedule_df['arenaState'].astype('string')
df['ARENA_CITY'] = schedule_df['arenaCity'].astype('string')

# %%
df['HOME_TEAM_ID'] = pd.to_numeric(schedule_df['homeTeam_teamId'], downcast='unsigned')
df['AWAY_TEAM_ID'] = pd.to_numeric(schedule_df['awayTeam_teamId'], downcast='unsigned')

# %%
df.dtypes
# Out:
# GAME_ID              string[python]
# GAME_DATE       datetime64[ns, UTC]
# ARENA_NAME           string[python]
# ARENA_STATE          string[python]
# ARENA_CITY           string[python]
# HOME_TEAM_ID                 uint32
# AWAY_TEAM_ID                 uint32
# dtype: object

# %% [markdown]
# We need to check if the 'GAME_ID's are consistent with the one we got from the gamelogs.

# %%
from pathlib import Path

data_path = Path("~/MBAI/data").expanduser()
current_season_id = "22024"
current_season_path = data_path / f"rs{current_season_id}"

# %%
rs_game_ids = [
    game_dir.name[1:]
        for game_dir in current_season_path.iterdir()
            if game_dir.is_dir() and game_dir.name.startswith('g')
]

# %%
rs_games_df = df[df['GAME_ID'].isin(rs_game_ids)]

# %%
assert len(rs_games_df) == len(rs_game_ids), "We are missing some games!!!"

# %% [markdown]
# We can now get all the schedules and save them.

# %%
season_id = 2023
season_dir = data_path / f"rs{season_id}"
schedule = ScheduleLeagueV2(season=season_id)
schedule_df = schedule.get_data_frames()[0]

rs_game_ids = [
    game_dir.name[1:]
        for game_dir in season_dir.iterdir()
            if game_dir.is_dir() and game_dir.name.startswith('g')
]
schedule_df = schedule_df[schedule_df['gameId'].isin(rs_game_ids)]

assert len(schedule_df) == len(rs_game_ids)
    
df = pd.DataFrame()
df['GAME_ID'] = schedule_df['gameId'].astype('string')

dates = pd.to_datetime(schedule_df['gameDateUTC']).dt.normalize()
times = pd.to_datetime(schedule_df['gameTimeUTC']).dt.time
time_deltas = pd.to_timedelta(times.astype(str))
df['GAME_DATE'] = dates + time_deltas

df['ARENA_NAME'] = schedule_df['arenaName'].astype('string')
df['ARENA_STATE'] = schedule_df['arenaState'].astype('string')
df['ARENA_CITY'] = schedule_df['arenaCity'].astype('string')
        
df['HOME_TEAM_ID'] = pd.to_numeric(schedule_df['homeTeam_teamId'], downcast='unsigned')
df['AWAY_TEAM_ID'] = pd.to_numeric(schedule_df['awayTeam_teamId'], downcast='unsigned')

df.to_parquet(season_dir / "schedule.parquet")

# %%
for season_dir in data_path.iterdir():
    if season_dir.is_dir() and season_dir.name.startswith('rs'):
        season_id = season_dir.name[3:]
        schedule = ScheduleLeagueV2(season=season_id)
        schedule_df = schedule.get_data_frames()[0]

        rs_game_ids = [
            game_dir.name[1:]
                for game_dir in season_dir.iterdir()
                    if game_dir.is_dir() and game_dir.name.startswith('g')
        ]
        schedule_df = schedule_df[schedule_df['gameId'].isin(rs_game_ids)]

        assert len(schedule_df) == len(rs_game_ids)
            
        df = pd.DataFrame()
        df['GAME_ID'] = schedule_df['gameId'].astype('string')
        
        dates = pd.to_datetime(schedule_df['gameDateUTC']).dt.normalize()
        times = pd.to_datetime(schedule_df['gameTimeUTC']).dt.time
        time_deltas = pd.to_timedelta(times.astype(str))
        df['GAME_DATE'] = dates + time_deltas
        
        df['ARENA_NAME'] = schedule_df['arenaName'].astype('string')
        df['ARENA_STATE'] = schedule_df['arenaState'].astype('string')
        df['ARENA_CITY'] = schedule_df['arenaCity'].astype('string')
                
        df['HOME_TEAM_ID'] = pd.to_numeric(schedule_df['homeTeam_teamId'], downcast='unsigned')
        df['AWAY_TEAM_ID'] = pd.to_numeric(schedule_df['awayTeam_teamId'], downcast='unsigned')

        df.to_parquet(season_dir / "schedule.parquet")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/urllib3/connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[36], line 4
#       2 if season_dir.is_dir() and season_dir.name.startswith('rs'):
#       3     season_id = season_dir.name[3:]
# ----> 4     schedule = ScheduleLeagueV2(season=season_id)
#       5     schedule_df = schedule.get_data_frames()[0]
#       7     rs_game_ids = [
#       8         game_dir.name[1:]
#       9             for game_dir in season_dir.iterdir()
#      10                 if game_dir.is_dir() and game_dir.name.startswith('g')
#      11     ]
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/nba_api/stats/endpoints/scheduleleaguev2.py:191, in ScheduleLeagueV2.__init__(self, league_id, season, proxy, headers, timeout, get_request)
#     186 self.parameters = {
#     187     "LeagueID": league_id,
#     188     "Season": season,
#     189 }
#     190 if get_request:
# --> 191     self.get_request()
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/nba_api/stats/endpoints/scheduleleaguev2.py:194, in ScheduleLeagueV2.get_request(self)
#     193 def get_request(self):
# --> 194     self.nba_response = NBAStatsHTTP().send_api_request(
#     195         endpoint=self.endpoint,
#     196         parameters=self.parameters,
#     197         proxy=self.proxy,
#     198         headers=self.headers,
#     199         timeout=self.timeout,
#     200     )
#     201     self.load_response()
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/nba_api/library/http.py:160, in NBAHTTP.send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     157         print("loading from file...")
#     159 if not contents:
# --> 160     response = self.get_session().get(
#     161         url=base_url,
#     162         params=parameters,
#     163         headers=request_headers,
#     164         proxies=proxies,
#     165         timeout=timeout,
#     166     )
#     167     url = response.url
#     168     status_code = response.status_code
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/MBAI/lib/python3.13/site-packages/requests/adapters.py:690, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     688     raise SSLError(e, request=request)
#     689 elif isinstance(e, ReadTimeoutError):
# --> 690     raise ReadTimeout(e, request=request)
#     691 elif isinstance(e, _InvalidHeader):
#     692     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
